# %% [markdown]
# ### Creating clusters for the songs we scraped from spotify

# %%
# import libraries
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
from random import randint
from tqdm import tqdm

# %%
musicdata = pd.read_csv('spotifydata.csv') # read spotify data into dataframe
musicdata.drop(['Unnamed: 0'], axis = 1, inplace = True)  # drop weird new axis
original = musicdata  # make a copy
original
# Out:
#                             artist  \
# 0                waka flocka flame
# 1                      trick daddy
# 2                              dmx
# 3                              ugk
# 4     lil jon & the east side boyz
# ...                            ...
# 9838                         wilco
# 9839                  orville peck
# 9840                 michaela anne
# 9841                  joan shelley
# 9842                  che apalache
#
#                                                   title  \
# 0                   no hands (feat. roscoe dash & wale)
# 1                                   take it to da house
# 2                                   ruff ryders' anthem
# 3     int'l players anthem (i choose you) (feat. out...
# 4                                        what u gon' do
# ...                                                 ...
# 9838                        love is everywhere (beware)
# 9839                                      dead of night
# 9840                                        desert dove
# 9841                                coming down for you
# 9842                                        the dreamer
#
#                          tid  danceability  energy  key  loudness  mode  \
# 0     03tqyYWC9Um2ZqU0ZN849H         0.760   0.595    1    -6.366     1
# 1     1wLhwzPAtze5JT8qqXlqaO         0.935   0.780    6    -5.795     0
# 2     1BKT2I9x4RGKaKqW4up34s         0.880   0.577   10    -8.093     0
# 3     4ns1XFP3W5JPyzvnAjMdHD         0.675   0.680    4    -5.010     0
# 4     1bTphHXspys3RvvRxfzzIc         0.838   0.724    1    -6.900     0
# ...                      ...           ...     ...  ...       ...   ...
# 9838  7sxr5Pvovng4ECTiCqeSWm         0.313   0.520    7    -9.436     1
# 9839  4WDazmiEd5PyY3taS11VfD         0.454   0.548    2   -11.618     1
# 9840  7oC1Lo7hqhpxIU8d5iH6cc         0.592   0.419    2    -9.441     1
# 9841  4bDALATwj7AYLJ9h8cImWf         0.528   0.338    5   -10.942     0
# 9842  3TwNSH4IkiBSrFH0wwfmn1         0.295   0.426    3    -8.734     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0          0.0391      0.005440          0.000000    0.2410    0.361  131.497
# 1          0.1970      0.015800          0.000000    0.1640    0.918  123.895
# 2          0.3020      0.056400          0.000001    0.2010    0.740   90.991
# 3          0.2560      0.065500          0.000000    0.3540    0.845  155.698
# 4          0.2420      0.000077          0.000001    0.1620    0.537  150.192
# ...           ...           ...               ...       ...      ...      ...
# 9838       0.0298      0.120000          0.452000    0.0993    0.511  144.249
# 9839       0.0547      0.820000          0.356000    0.0606    0.500   99.892
# 9840       0.0296      0.349000          0.001020    0.0896    0.370  119.868
# 9841       0.0302      0.969000          0.077900    0.1600    0.555   92.262
# 9842       0.0343      0.824000          0.000157    0.1130    0.381  184.125
#
# [9843 rows x 14 columns]

# %%
# first i drop the unnecessary columns for the model
musicdata = musicdata.drop(['artist', 'title', 'tid'], axis = 1)

# %%
# define x as the variables we want to cluster
X = musicdata
# scale numerical values
X_prep = StandardScaler().fit_transform(X)
# look at the array

# %%
# create a dataframe from the scaled array
X_prep_df = pd.DataFrame(X_prep, columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])
X_prep_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         1.026783  0.314932 -1.193932  0.630667  0.738549    -0.424550
# 1         1.933218  0.972119  0.215672  0.709186 -1.354006     1.270515
# 2         1.648338  0.250989  1.343356  0.393186 -1.354006     2.397696
# 3         0.586515  0.616882 -0.348169  0.817133 -1.354006     1.903883
# 4         1.430794  0.773186 -1.193932  0.557236 -1.354006     1.753593
# ...            ...       ...       ...       ...       ...          ...
# 9838     -1.288509  0.048504  0.497593  0.208508  0.738549    -0.524386
# 9839     -0.558182  0.147970 -0.912011 -0.091541  0.738549    -0.257083
# 9840      0.156606 -0.310285 -0.912011  0.207821  0.738549    -0.526533
# 9841     -0.174890 -0.598026 -0.066248  0.001416 -1.354006    -0.520092
# 9842     -1.381743 -0.285418 -0.630090  0.305041  0.738549    -0.476078
#
#       acousticness  instrumentalness  liveness   valence     tempo
# 0        -1.229003         -0.594192  0.618417 -0.382922  0.491431
# 1        -1.200801         -0.594192  0.015207  1.638251  0.240988
# 2        -1.090281         -0.594189  0.305061  0.992346 -0.843011
# 3        -1.065509         -0.594192  1.503646  1.373357  1.288715
# 4        -1.243602         -0.594189 -0.000460  0.255725  1.107324
# ...            ...               ...       ...       ...       ...
# 9838     -0.917151          0.666271 -0.491645  0.161380  0.911536
# 9839      0.988367          0.398562 -0.794816  0.121464 -0.549774
# 9840     -0.293774         -0.591347 -0.567634 -0.350264  0.108321
# 9841      1.393970         -0.376957 -0.016128  0.321041 -0.801139
# 9842      0.999256         -0.593754 -0.384321 -0.310348  2.225223
#
# [9843 rows x 11 columns]

# %% [markdown]
# ### I first ran the model with 500 clusters, because I wanted to get Inertia as low as possible, but that lead to...interesting recommendations.
# After tuning the model and visualising shilouette score and K I settled for 81 clusters

# %%
# define the model, 50 clusters, define random state
kmeans = KMeans(n_clusters=81, random_state=1234)
# fit the model to the dataframe
kmeans.fit(X_prep_df)
# Out:
# KMeans(n_clusters=81, random_state=1234)

# %%
# take a look at the cluster centers
kmeans.cluster_centers_
# Out:
# array([[ 9.79220726e-01,  7.90454041e-01, -4.05077922e-02,
#          6.25479641e-01, -1.35400640e+00, -1.63800172e-01,
#         -7.63095094e-01, -4.75321662e-01, -4.46232407e-01,
#          1.11759878e+00, -2.44372397e-01],
#        [-9.88895779e-01, -1.66878429e+00,  8.13076147e-01,
#         -2.54108690e+00,  7.38548946e-01, -3.62951217e-01,
#          1.43133529e+00,  1.93596252e+00, -4.82827318e-01,
#         -9.33841227e-01, -9.55584860e-01],
#        [-1.82518073e-01,  5.49968825e-01, -6.83911331e-01,
#          6.19796516e-01, -1.35400640e+00, -1.26788843e-01,
#         -7.58730742e-01, -5.41427885e-01, -3.91542285e-01,
#         -4.69248025e-01,  9.75783333e-01],
#        [-9.97302127e-01, -9.82908550e-01, -8.39066369e-01,
#         -3.64114439e-01,  7.38548946e-01, -3.90355456e-01,
#          1.08646039e+00, -5.15251152e-01, -2.26185937e-01,
#         -8.18695353e-01,  1.29999602e+00],
#        [-3.31533351e-01,  1.02337439e+00,  7.47995041e-01,
#          7.39256819e-01,  7.38548946e-01, -1.75963455e-01,
#         -1.03557142e+00, -5.31060234e-01, -3.52683645e-01,
#         -3.64798729e-01,  1.92323685e-01],
#        [-4.26208526e-01, -5.32490431e-01,  9.78602572e-01,
#          6.52908927e-02,  7.38548946e-01, -3.97989023e-01,
#          6.09831325e-01, -4.99857936e-01, -2.47401501e-01,
#         -6.23598431e-01,  9.59676035e-01],
#        [ 8.31129016e-01,  4.59352017e-01, -1.02947794e+00,
#          1.70106444e-01,  7.38548946e-01, -6.44144572e-02,
#         -9.34329289e-01,  1.65055911e+00, -4.07813198e-01,
#          7.16134997e-01,  3.92780735e-02],
#        [ 6.98616932e-01, -9.25892338e-01, -1.06522797e-01,
#         -1.02924642e+00, -1.08437742e-01,  8.88754768e+00,
#          4.08545184e-01, -5.92164839e-01,  3.71835641e-01,
#          3.35471224e-04, -3.55441618e-01],
#        [-6.76822391e-01, -9.61639605e-01,  9.47208437e-01,
#         -2.55045666e-01,  7.38548946e-01, -4.43891591e-01,
#          1.08540307e+00, -5.02207368e-01, -2.47224487e-01,
#         -8.55236227e-01, -7.65955028e-01],
#        [ 7.53156091e-01, -5.89831118e-01,  3.32329354e-01,
#         -4.07176892e-01,  5.94234784e-01,  4.06311008e+00,
#          5.28599398e-01, -4.47163533e-01,  1.37496973e-01,
#          3.62458262e-01, -5.30317269e-02],
#        [-1.64104089e-01,  9.53604763e-01, -7.09691259e-01,
#          6.85023143e-01, -1.35400640e+00, -1.32657531e-01,
#         -9.53644479e-01, -4.99680067e-01,  1.21932165e+00,
#         -8.85892473e-02,  8.16017081e-02],
#        [-1.62492908e+00, -1.40231930e+00, -1.03804612e+00,
#         -1.57324693e+00, -1.35400640e+00, -3.89174821e-01,
#          1.24897156e+00,  1.88470711e+00, -3.47317276e-01,
#         -1.32808091e+00, -1.02486105e+00],
#        [ 9.28243984e-01,  7.35063532e-01, -1.15038302e+00,
#          6.81221205e-01,  7.38548946e-01,  1.64519475e+00,
#         -7.96571090e-01, -5.70972554e-01, -2.04631905e-01,
#          5.38673357e-01, -4.89792347e-01],
#        [-7.71600303e-01, -8.16978118e-01,  2.68233966e-01,
#         -6.11163436e-01,  2.06543349e-01, -3.40907532e-01,
#          1.00373124e+00,  1.94584329e-01,  3.78304086e+00,
#         -7.97882443e-01, -5.17063952e-01],
#        [ 3.47827711e-01,  5.81125863e-01,  8.44217286e-01,
#          6.08167415e-01,  7.38548946e-01,  2.35651553e+00,
#         -6.17121606e-01, -5.40474659e-01, -1.16389127e-01,
#          4.90220885e-01,  1.81537915e+00],
#        [-1.62373322e+00, -1.64032544e+00, -9.24209421e-01,
#         -2.25105721e+00,  7.38548946e-01, -3.84696093e-01,
#          1.39438908e+00,  1.84256499e+00, -3.75993596e-01,
#         -1.26285131e+00, -1.29941525e+00],
#        [-1.30610583e+00, -1.36026202e+00,  3.47580371e-01,
#         -1.67742622e+00,  7.38548946e-01, -3.67801924e-01,
#          1.31560179e+00,  1.83420199e+00, -3.49204934e-01,
#         -9.46138935e-01,  1.55334550e+00],
#        [-1.02453989e+00, -9.85377887e-01, -9.32439970e-01,
#         -6.90697457e-01,  7.38548946e-01, -4.14126090e-01,
#          1.03038322e+00,  1.66848172e+00, -2.11578006e-01,
#         -1.03904954e+00, -2.51973791e-01],
#        [ 8.97384077e-01,  1.08180280e+00,  7.59590407e-01,
#          7.44649591e-01,  7.38548946e-01, -1.18570577e-01,
#         -9.25985566e-01, -5.42121258e-01, -5.28885126e-01,
#          1.23330069e+00,  6.90135603e-03],
#        [ 9.35240364e-01,  1.03014575e+00, -1.17034006e+00,
#          7.32072402e-01,  7.38548946e-01, -1.93090525e-01,
#         -8.02007529e-01, -5.42814149e-01, -4.70005222e-01,
#          1.11037701e+00, -1.24168751e-01],
#        [-2.62842954e-01,  8.53304343e-01,  1.17913010e+00,
#          6.59635532e-01, -1.35400640e+00, -1.38643167e-01,
#         -8.41572535e-01, -5.54592866e-01, -2.32716160e-01,
#         -4.44685269e-02, -6.98860405e-01],
#        [-4.89235427e-02, -4.74299412e-01, -9.97749737e-01,
#          1.16945479e-01,  7.38548946e-01, -3.86540143e-01,
#          6.97698443e-01, -5.38521643e-01, -2.98467131e-01,
#         -3.22455738e-01, -9.29065786e-01],
#        [ 2.66202464e-03, -5.03827993e-01, -8.83243490e-01,
#          1.18680259e-02, -1.35400640e+00, -3.55509706e-01,
#          7.75112063e-01, -5.02542129e-01, -2.73937684e-01,
#         -2.91950672e-01, -3.17474329e-01],
#        [ 1.10158506e+00,  3.48379086e-01,  1.16761297e+00,
#          4.99419229e-01, -1.35400640e+00,  2.58144658e+00,
#         -6.59992186e-01, -4.84519227e-01, -5.11619785e-02,
#          4.21041959e-01, -2.84664584e-01],
#        [ 6.79324234e-01,  9.89319769e-01, -1.10490413e+00,
#          6.92397858e-01,  7.38548946e-01, -9.48331360e-02,
#         -6.99286355e-01, -5.46870754e-01,  1.21979325e+00,
#          8.87242072e-01, -2.25177270e-01],
#        [-6.58265907e-01,  1.07949192e+00,  9.09864639e-01,
#          7.26894175e-01, -1.35400640e+00,  2.28106715e-01,
#         -1.02380641e+00, -4.96534485e-01,  1.39454428e-01,
#         -3.52788207e-01,  1.36912435e+00],
#        [-1.62934395e+00, -1.41112248e+00, -1.40874497e-01,
#         -1.44875846e+00, -1.35400640e+00, -3.74363603e-01,
#          1.28408274e+00, -4.39502971e-01, -2.25650116e-01,
#         -1.28053885e+00, -6.94513508e-01],
#        [-5.69772478e-02, -8.43334552e-01,  6.30261930e-01,
#         -6.81762220e-01,  7.38548946e-01, -2.91330059e-01,
#          9.85751719e-01,  1.71362169e+00, -3.06174015e-01,
#         -3.76717500e-01, -2.63121236e-01],
#        [-1.87293975e+00, -1.55166314e+00,  2.51732096e-01,
#         -1.93098200e+00,  7.38548946e-01, -3.39930291e-01,
#          1.32908138e+00, -4.11065559e-01, -3.30922914e-01,
#         -1.44152474e+00, -9.03809187e-01],
#        [-6.56563014e-03,  7.64631031e-01, -1.06846961e+00,
#          6.29843053e-01,  7.38548946e-01, -2.52159618e-01,
#         -9.10943456e-01, -5.13641069e-01, -3.20685924e-01,
#         -2.73086934e-01, -4.55381428e-01],
#        [ 3.79288914e-01,  8.99859253e-01, -1.05297135e+00,
#          6.88729859e-01,  7.38548946e-01,  2.67312694e-02,
#         -7.64771440e-01, -5.35897809e-01, -2.11235510e-01,
#          1.11695969e+00,  1.60525209e+00],
#        [ 5.86296182e-01,  4.13647196e-01,  2.07731021e-01,
#          9.84584615e-02, -1.35400640e+00, -2.49629071e-01,
#          1.45634331e-03,  1.71130168e+00, -6.82401219e-02,
#          1.11531247e+00,  4.13290499e-01],
#        [ 9.34652701e-01,  4.93924813e-01,  9.50485492e-01,
#          5.63633805e-01, -1.35400640e+00, -1.87603085e-01,
#         -8.21527146e-01, -5.17626119e-01, -3.23959512e-01,
#         -3.72513377e-01, -1.36942417e-01],
#        [ 8.77181329e-01,  6.30321440e-02, -8.53682473e-01,
#          7.86207073e-02,  7.38548946e-01, -2.72896976e-01,
#         -7.06547969e-01, -5.56772869e-01, -4.89051816e-01,
#          1.25085823e+00, -1.74809510e-01],
#        [ 5.57277417e-01,  7.35325741e-01,  1.00579271e+00,
#          6.43826858e-01, -1.35400640e+00,  5.25996737e-01,
#         -6.07712778e-01, -5.62680998e-01, -1.21854766e-01,
#          1.07800220e+00,  1.78878470e+00],
#        [ 4.52641644e-01,  7.09927057e-01,  2.64466445e-01,
#          6.41480539e-01, -2.67487278e-01,  2.65802098e+00,
#         -6.61172922e-01, -5.69275964e-01,  3.45880276e+00,
#          6.59938703e-01,  1.96354320e-01],
#        [-7.20684292e-01, -7.07865150e-01,  2.53261899e-01,
#         -1.71778174e-01, -1.35400640e+00, -3.56260722e-01,
#          9.53015238e-01, -4.65931826e-01, -2.29690404e-01,
#         -6.96173322e-01,  1.25887059e+00],
#        [ 1.56389020e-01, -4.85370258e-02, -1.06225616e+00,
#          3.66566886e-01,  7.38548946e-01, -3.80214850e-01,
#         -4.31018991e-01, -5.40412882e-01, -2.86561476e-01,
#         -6.44006144e-01,  5.46627135e-01],
#        [ 6.27760204e-01,  9.05150208e-01,  7.72988196e-01,
#          6.33457731e-01,  7.38548946e-01, -1.08323103e-01,
#         -8.12450970e-01, -5.17473413e-01,  1.23210719e+00,
#          8.55313438e-01, -1.21316116e-01],
#        [ 1.78090093e-01, -8.84295847e-01, -6.10647262e-01,
#         -1.48190504e-01,  7.38548946e-01, -4.19552631e-01,
#          1.00840123e+00, -5.45800438e-01, -3.50631298e-01,
#         -5.64067829e-01,  2.21488197e-01],
#        [ 5.61393856e-01,  5.80648332e-01,  8.03007545e-01,
#          2.02381955e-01,  7.38548946e-01, -1.80023329e-01,
#         -3.94701113e-01,  1.71005661e+00, -4.67064983e-02,
#          1.07961601e+00,  4.73746153e-01],
#        [-1.23223905e+00, -1.52314137e+00,  1.11693121e+00,
#         -1.87491298e+00, -1.35400640e+00, -3.62159874e-01,
#          1.36666286e+00,  1.85414115e+00, -3.67659980e-01,
#         -1.12896331e+00, -7.56258697e-01],
#        [ 6.70022111e-01,  4.84695033e-01,  1.19926295e+00,
#          2.77121573e-01, -1.35400640e+00, -2.17983675e-01,
#         -9.19268885e-01,  1.58348361e+00, -1.28170207e-01,
#         -3.31019663e-01, -9.16050002e-02],
#        [-1.50874953e+00, -1.72214212e+00, -1.52988408e-02,
#         -2.81979626e+00, -1.35400640e+00, -3.69426124e-01,
#          1.42001127e+00,  1.89414341e+00, -5.13306269e-01,
#         -1.14492628e+00, -1.32332001e+00],
#        [ 7.79906187e-01,  2.32600242e-01,  8.68462429e-01,
#          2.84861344e-01,  7.38548946e-01, -2.35113582e-01,
#          2.00548197e-01, -5.43192799e-01, -2.98952457e-01,
#          1.32267229e+00, -1.27407632e-01],
#        [ 2.49727997e-01, -4.28100821e-01,  8.82581977e-01,
#          1.27551697e-01,  7.38548946e-01, -3.48804361e-01,
#          7.38308126e-01, -5.58614184e-01, -2.71087521e-01,
#          1.94603409e-01, -6.20573492e-01],
#        [ 3.89886592e-01, -2.40658232e-01,  9.40611767e-01,
#         -1.26195312e-03, -1.35400640e+00, -2.62767597e-01,
#          4.52067374e-01, -5.61115033e-01, -2.35656095e-01,
#          4.67017754e-01,  2.92720401e-01],
#        [-9.64280748e-01,  8.35161552e-01, -9.05505058e-01,
#          6.50443623e-01,  7.38548946e-01, -1.13059984e-01,
#         -9.35980303e-01, -3.05060314e-01, -1.51130188e-01,
#         -4.88806588e-01,  1.60058035e+00],
#        [ 4.23827714e-01,  8.38905197e-01, -6.08732439e-01,
#          5.39997528e-01,  7.38548946e-01,  9.20501273e-02,
#         -6.70575648e-01, -4.18359686e-01,  3.77511645e+00,
#          5.84125808e-01, -2.53951447e-01],
#        [ 2.26781700e-01,  7.65814353e-01, -7.42252135e-01,
#          6.43146909e-01, -1.35400640e+00, -6.64031632e-02,
#         -4.16932012e-01, -4.81413695e-01, -2.31880186e-01,
#          1.15754865e+00,  1.46839613e+00],
#        [-5.33230864e-01, -1.24700897e+00, -8.33194343e-01,
#         -1.38591187e+00, -1.35400640e+00, -4.01510017e-01,
#          1.29222557e+00,  1.89917697e+00, -4.28308557e-01,
#         -8.69523365e-01,  1.84448643e-01],
#        [ 8.98349105e-01,  3.37995359e-01,  6.75722388e-01,
#          4.96683621e-01,  7.38548946e-01, -7.41118662e-02,
#         -8.13092188e-01, -5.53291434e-01, -3.73131271e-01,
#          9.90602150e-02, -2.88337161e-01],
#        [-4.11373405e-01,  8.61371866e-01,  8.93573719e-01,
#          6.68023204e-01,  7.38548946e-01, -7.88648320e-02,
#         -8.38707525e-01, -4.95416298e-01, -1.05255127e-01,
#          5.72915735e-01,  1.75283669e+00],
#        [ 2.43885238e-01, -8.21364772e-02, -1.04374964e+00,
#         -3.60266398e-02,  7.38548946e-01, -2.71349717e-01,
#         -7.88817459e-02,  1.60729154e+00, -2.15233395e-01,
#         -6.67959405e-01, -1.92676681e-01],
#        [-6.22024072e-01, -2.18336168e-01, -3.21944040e-01,
#         -8.16884809e-02,  2.03244090e-01, -8.23264250e-02,
#          7.05660411e-01, -3.02641853e-01,  4.47141309e+00,
#          7.27898079e-03,  1.24731217e+00],
#        [ 3.01635641e-01,  3.23516382e-01, -6.97214090e-01,
#          1.42162208e-01, -1.35400640e+00, -2.45696304e-01,
#         -7.88236099e-01,  1.59153303e+00, -2.20518043e-01,
#         -7.40303205e-01,  5.22610069e-01],
#        [-1.87675871e+00, -1.36316804e+00,  6.15382143e-01,
#         -1.36111423e+00,  7.38548946e-01, -4.15447245e-01,
#          1.20567451e+00,  1.79669908e+00, -3.80398558e-01,
#         -1.41148493e+00, -1.07677072e+00],
#        [-1.00399994e+00, -1.61338000e+00, -7.60981900e-01,
#         -2.30770980e+00,  7.38548946e-01, -3.53644947e-01,
#          1.40056182e+00,  1.89191538e+00, -4.31833384e-01,
#         -8.64395282e-01,  3.42270657e-01],
#        [ 1.01270813e+00,  9.20068993e-01, -4.09456375e-01,
#          7.52883451e-01, -1.35400640e+00, -9.02463772e-02,
#         -5.23382940e-01, -5.64975703e-01,  1.23252506e+00,
#          1.12045439e+00, -8.85844224e-02],
#        [ 7.26966430e-01, -3.60077252e-01, -7.61046858e-01,
#          5.46889591e-02,  7.25048589e-01, -2.58544482e-01,
#          7.17818683e-01, -5.39308107e-01, -3.49563684e-01,
#          9.63504231e-01, -3.71785960e-02],
#        [-1.11471193e+00, -1.01047232e+00, -8.92962218e-01,
#         -3.39458179e-01,  7.38548946e-01, -3.84431343e-01,
#          1.08923453e+00, -5.24875683e-01, -2.40293816e-01,
#         -1.00942008e+00, -8.57259507e-01],
#        [-1.48997565e+00, -1.45129012e+00,  3.59509618e-01,
#         -1.84286546e+00, -1.35400640e+00, -3.73054583e-01,
#          1.31277744e+00,  1.77486247e+00, -4.10580372e-01,
#         -9.96193975e-01,  1.47381433e+00],
#        [-2.47212815e-01,  1.06448031e+00,  1.04055196e+00,
#          6.89379581e-01, -2.68977703e-01,  1.75340778e-01,
#         -8.98536010e-01, -3.69763528e-01,  4.97057534e+00,
#          1.95381602e-01,  5.74933450e-01],
#        [ 3.46653620e-01,  7.07708938e-01, -1.40408273e-02,
#          6.21724080e-01, -1.35400640e+00,  2.57886652e+00,
#         -5.93359666e-01, -5.08627346e-01,  7.00832000e-02,
#          3.89134977e-01,  1.69580201e+00],
#        [-4.96065327e-01, -7.44407311e-01,  8.67877391e-01,
#         -5.33552831e-02, -1.35400640e+00, -3.91719943e-01,
#          9.11801060e-01, -5.18795628e-01, -1.47094433e-01,
#         -6.75108768e-01, -6.55794116e-01],
#        [ 2.04354441e-01,  1.16924522e-01, -5.21112274e-01,
#          4.22622229e-01, -1.35400640e+00, -2.48910055e-01,
#         -6.81971418e-01, -5.37018046e-01, -2.36701491e-01,
#         -6.56813674e-01, -7.04430017e-01],
#        [ 8.31047881e-01,  4.90555395e-01, -9.51578761e-01,
#          5.47323563e-01,  7.38548946e-01,  2.81372636e+00,
#         -6.78951171e-01, -5.59010332e-01, -2.81243421e-01,
#          3.90374480e-01,  1.07713220e+00],
#        [ 3.01693839e-01,  5.35896528e-01,  6.27466945e-01,
#          2.82377848e-01,  7.38548946e-01, -2.42222919e-01,
#         -9.92117016e-01,  1.63455356e+00, -2.92382734e-01,
#         -5.96426593e-01, -1.16502602e-01],
#        [ 6.69930405e-02, -6.34424416e-01,  6.27943795e-01,
#         -4.31538448e-01, -1.35400640e+00, -2.95302233e-01,
#          8.79275490e-01,  1.76052489e+00, -2.60545470e-01,
#         -6.83305959e-01, -4.28229478e-01],
#        [-4.03302887e-01,  1.09301570e+00, -6.57819998e-01,
#          6.56258005e-01,  6.01332202e-01,  3.23155377e-01,
#         -7.86223521e-01, -3.47137499e-01,  1.71657321e+00,
#          7.77719094e-01,  1.95359288e+00],
#        [-2.84109653e-01, -4.47750169e-05,  6.47254980e-01,
#          3.40208137e-01,  7.38548946e-01, -3.61014363e-01,
#         -5.72754455e-01, -5.20356859e-01, -2.95111282e-01,
#         -6.17509003e-01, -8.31271118e-01],
#        [ 5.42558218e-01,  1.06204806e+00,  1.12239084e+00,
#          6.75861502e-01, -1.35400640e+00,  7.44849929e-02,
#         -8.54624838e-01, -4.76333288e-01,  1.63110507e+00,
#          9.28632034e-01, -7.47751955e-02],
#        [ 7.26207010e-01,  6.78117403e-01, -1.15955118e+00,
#          5.73793112e-01, -1.35400640e+00, -1.06812001e-01,
#         -5.17830019e-01, -4.86584800e-01, -4.17433364e-01,
#          7.13690592e-01, -3.67167931e-01],
#        [-3.03212578e-01, -3.26900576e-01, -1.82333444e-01,
#          2.74880909e-02,  7.18033697e-01, -2.03628872e-01,
#          7.24210012e-01, -3.81486025e-01, -1.22208261e-01,
#          8.88893513e-01,  1.96534798e+00],
#        [-6.12794539e-01,  1.05761701e+00, -1.45624163e-01,
#          6.60953236e-01,  7.38548946e-01, -1.28064448e-01,
#         -1.08650740e+00, -3.21790433e-01,  1.58700426e+00,
#         -6.12666332e-01,  1.84165946e-01],
#        [ 1.03798239e+00,  8.29944279e-01,  1.31033807e+00,
#          6.75178902e-01, -1.35400640e+00, -1.59070693e-02,
#         -7.86070166e-01, -4.91603298e-01, -3.58730172e-01,
#          1.17549641e+00, -2.13471410e-01],
#        [ 7.00815008e-01,  7.39364375e-01,  7.98466803e-01,
#          6.58875681e-01,  7.38548946e-01,  2.06770573e+00,
#         -7.39094872e-01, -5.63276594e-01, -1.07284380e-01,
#          6.99704311e-01, -7.36361066e-01],
#        [ 3.10699986e-01,  7.50036891e-01, -1.36728602e-01,
#          5.68659025e-01, -1.35400640e+00,  1.22848349e-01,
#         -4.83925209e-01, -2.40462645e-01,  3.79584063e+00,
#          2.04476139e-01, -3.48357608e-02],
#        [ 1.18664066e+00,  6.24997159e-01,  1.66695043e-02,
#          6.75706356e-01, -1.35400640e+00,  1.46785072e+00,
#         -7.09834859e-01, -5.59679678e-01, -3.66356691e-01,
#          6.54594889e-01, -5.01865942e-01],
#        [ 6.11919773e-02,  5.75749809e-01, -4.22358931e-01,
#          5.60966119e-01, -1.35400640e+00,  2.59055022e+00,
#         -4.19569757e-01, -5.28120951e-01,  3.26892479e-02,
#          3.61860727e-01, -9.46195292e-01],
#        [ 3.02050954e-02, -3.29074703e-01, -2.26992732e-01,
#          1.48222694e-01,  7.01837449e-01, -3.64838596e-01,
#          7.06551030e-01, -5.24615975e-01,  1.42537549e+00,
#          4.25604467e-01, -2.04677346e-01]])

# %%
#inertia for the model. It's quite high
kmeans.inertia_
# Out:
# 23662.2257467084

# %%
# get the actual cluster into a variable
clusters = kmeans.predict(X_prep)

# %%
# create a new dataframe the original variables used before scaling
X_df = pd.DataFrame(X)
# add clusters to the dataframe
X_df['cluster'] = clusters
X_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.760   0.595    1    -6.366     1       0.0391      0.005440
# 1         0.935   0.780    6    -5.795     0       0.1970      0.015800
# 2         0.880   0.577   10    -8.093     0       0.3020      0.056400
# 3         0.675   0.680    4    -5.010     0       0.2560      0.065500
# 4         0.838   0.724    1    -6.900     0       0.2420      0.000077
#
#    instrumentalness  liveness  valence    tempo  cluster
# 0          0.000000     0.241    0.361  131.497       37
# 1          0.000000     0.164    0.918  123.895       78
# 2          0.000001     0.201    0.740   90.991       23
# 3          0.000000     0.354    0.845  155.698       63
# 4          0.000001     0.162    0.537  150.192       63

# %%
# take alook at cluster dristibution
X_df['cluster'].plot(kind='hist');

# %%
# songs per cluster overview
X_df['cluster'].value_counts()
# Out:
# 18    283
# 19    239
# 8     232
# 0     230
# 75    222
#      ...
# 35     52
# 54     43
# 7      42
# 9      29
# 62     27
# Name: cluster, Length: 81, dtype: int64

# %%
# tuning the model for inertia
K = range(2, 100)
inertia = []

for k in tqdm(K):
    kmeans = KMeans(n_clusters=k,
                    random_state=17)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# 100%|██████████| 98/98 [01:29<00:00,  1.10it/s]
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# tune for shilouette

K = range(2, 100)
silhouette = []

for k in tqdm(K):
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep,
                                       kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# 100%|██████████| 98/98 [02:48<00:00,  1.72s/it]
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
clusters.shape
# Out:
# (9843,)

# %%
# create dataframe from scaled vales
musicclustered = pd.DataFrame(X_prep,  columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

# %%
# add cluster ID to the dataframe
musicclustered['cluster_id'] = clusters

# %%
# adding Trackid, title and artist back to the dataframe
musicclustered['tid'] = original['tid']
musicclustered['artist'] = original['artist']
musicclustered['title'] = original['title']
musicclustered
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         1.026783  0.314932 -1.193932  0.630667  0.738549    -0.424550
# 1         1.933218  0.972119  0.215672  0.709186 -1.354006     1.270515
# 2         1.648338  0.250989  1.343356  0.393186 -1.354006     2.397696
# 3         0.586515  0.616882 -0.348169  0.817133 -1.354006     1.903883
# 4         1.430794  0.773186 -1.193932  0.557236 -1.354006     1.753593
# ...            ...       ...       ...       ...       ...          ...
# 9838     -1.288509  0.048504  0.497593  0.208508  0.738549    -0.524386
# 9839     -0.558182  0.147970 -0.912011 -0.091541  0.738549    -0.257083
# 9840      0.156606 -0.310285 -0.912011  0.207821  0.738549    -0.526533
# 9841     -0.174890 -0.598026 -0.066248  0.001416 -1.354006    -0.520092
# 9842     -1.381743 -0.285418 -0.630090  0.305041  0.738549    -0.476078
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -1.229003         -0.594192  0.618417 -0.382922  0.491431
# 1        -1.200801         -0.594192  0.015207  1.638251  0.240988
# 2        -1.090281         -0.594189  0.305061  0.992346 -0.843011
# 3        -1.065509         -0.594192  1.503646  1.373357  1.288715
# 4        -1.243602         -0.594189 -0.000460  0.255725  1.107324
# ...            ...               ...       ...       ...       ...
# 9838     -0.917151          0.666271 -0.491645  0.161380  0.911536
# 9839      0.988367          0.398562 -0.794816  0.121464 -0.549774
# 9840     -0.293774         -0.591347 -0.567634 -0.350264  0.108321
# 9841      1.393970         -0.376957 -0.016128  0.321041 -0.801139
# 9842      0.999256         -0.593754 -0.384321 -0.310348  2.225223
#
#       cluster_id                     tid                        artist  \
# 0             37  03tqyYWC9Um2ZqU0ZN849H             waka flocka flame
# 1             78  1wLhwzPAtze5JT8qqXlqaO                   trick daddy
# 2             23  1BKT2I9x4RGKaKqW4up34s                           dmx
# 3             63  4ns1XFP3W5JPyzvnAjMdHD                           ugk
# 4             63  1bTphHXspys3RvvRxfzzIc  lil jon & the east side boyz
# ...          ...                     ...                           ...
# 9838          52  7sxr5Pvovng4ECTiCqeSWm                         wilco
# 9839          21  4WDazmiEd5PyY3taS11VfD                  orville peck
# 9840          37  7oC1Lo7hqhpxIU8d5iH6cc                 michaela anne
# 9841          22  4bDALATwj7AYLJ9h8cImWf                  joan shelley
# 9842           3  3TwNSH4IkiBSrFH0wwfmn1                  che apalache
#
#                                                   title
# 0                   no hands (feat. roscoe dash & wale)
# 1                                   take it to da house
# 2                                   ruff ryders' anthem
# 3     int'l players anthem (i choose you) (feat. out...
# 4                                        what u gon' do
# ...                                                 ...
# 9838                        love is everywhere (beware)
# 9839                                      dead of night
# 9840                                        desert dove
# 9841                                coming down for you
# 9842                                        the dreamer
#
# [9843 rows x 15 columns]

# %%
sns.scatterplot(data=musicclustered, x="danceability", y="tempo",hue='cluster_id');

# %%
sns.scatterplot(data=musicclustered, x="cluster_id", y="danceability",hue='acousticness', legend=False);

# %% [markdown]
# # Clustering is done. Let's try to predict a cluster

# %%
# set clientID and client secret in global variables
import getpass 
clientid = '297ada524bde40a8a7e580b18966dbba'
clientsecret = getpass.getpass()
# Out:
# ········

# %%
# set the Auth token
sp=spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=clientid, client_secret=clientsecret))

# %%
# try with a track id
features = sp.audio_features('47EiUVwUp4C9fGccaPuUCS')[0]

# %%
# convert features into an np array
data = list(features.items())
features
predicter = pd.DataFrame(features, index=[0])
predicter = predicter.drop(['type','id','uri','track_href','analysis_url', 'duration_ms', 'time_signature'],axis =1)
predicter
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.731   0.573    4   -10.059     0       0.0544         0.401
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000052     0.113    0.145  109.928

# %%
# safe the original scaler in a variable, so I can call it again later
scaler = StandardScaler().fit(X.drop(['cluster'], axis = 1))

# %%
# transform the song features into a scales array
predicter_scaled = scaler.transform(predicter)
predicter_scaled
# Out:
# array([[ 0.87657406,  0.23677949, -0.34816924,  0.12283861, -1.3540064 ,
#         -0.26030365, -0.15222159, -0.59404605, -0.38432087, -1.16671582,
#         -0.2191448 ]])

# %%
# predict cluster for that song
kmeans.predict(predicter_scaled)
# Out:
# array([65], dtype=int32)

# %% [markdown]
# ## Predicting a cluster works. Now let's build the function that gives a recommendation back

# %%
# first get the track ID of a song that is beeing searched
a = sp.search(q= 'white washed')
a['tracks']['items'][0]['id']
# Out:
# '0jCUZSnjn6hxp7zgX3h2rF'

# %%
# now get the features with the trackID
features=sp.audio_features(tracks='0jCUZSnjn6hxp7zgX3h2rF')
features
# Out:
# [{'danceability': 0.213,
#   'energy': 0.964,
#   'key': 10,
#   'loudness': -5.248,
#   'mode': 0,
#   'speechiness': 0.0737,
#   'acousticness': 7.05e-06,
#   'instrumentalness': 0.114,
#   'liveness': 0.453,
#   'valence': 0.335,
#   'tempo': 106.537,
#   'type': 'audio_features',
#   'id': '0jCUZSnjn6hxp7zgX3h2rF',
#   'uri': 'spotify:track:0jCUZSnjn6hxp7zgX3h2rF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0jCUZSnjn6hxp7zgX3h2rF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jCUZSnjn6hxp7zgX3h2rF',
#   'duration_ms': 226253,
#   'time_signature': 4}]

# %%
# check if I can access the dictionary
features[0]
# Out:
# {'danceability': 0.213,
#  'energy': 0.964,
#  'key': 10,
#  'loudness': -5.248,
#  'mode': 0,
#  'speechiness': 0.0737,
#  'acousticness': 7.05e-06,
#  'instrumentalness': 0.114,
#  'liveness': 0.453,
#  'valence': 0.335,
#  'tempo': 106.537,
#  'type': 'audio_features',
#  'id': '0jCUZSnjn6hxp7zgX3h2rF',
#  'uri': 'spotify:track:0jCUZSnjn6hxp7zgX3h2rF',
#  'track_href': 'https://api.spotify.com/v1/tracks/0jCUZSnjn6hxp7zgX3h2rF',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jCUZSnjn6hxp7zgX3h2rF',
#  'duration_ms': 226253,
#  'time_signature': 4}

# %%
# create a dataframe from the dictionary
new = pd.DataFrame([features[0]])
final = new.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis = 1)

# %%
# take a look at the dataframe
final
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.213   0.964   10    -5.248     0       0.0737      0.000007
#
#    instrumentalness  liveness  valence    tempo
# 0             0.114     0.453    0.335  106.537

# %%
# looks good, just needs to be scaled
predictor = scaler.transform(final)

# %%
# predict and store result in a variable
bro = kmeans.predict(final)

# %%
# check output
bro
# Out:
# array([31], dtype=int32)

# %%
# can I access only the clusternumber?
bro[0]
# Out:
# 31

# %%
# now filter the musicdatabase for the cluster
temp = musicclustered[musicclustered["cluster_id"]==31]
temp
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 154      -0.713571  0.112447 -0.912011 -0.833827  0.738549     0.192716
# 171      -0.817163 -0.388437 -0.348169 -0.021961  0.738549    -0.446020
# 177      -1.200456 -0.132666  1.343356 -0.881681  0.738549    -0.402006
# 190      -0.273303  0.485445 -0.066248  0.211121  0.738549    -0.279627
# 193      -1.573389 -0.050962  1.625277 -0.814713  0.738549    -0.452461
# ...            ...       ...       ...       ...       ...          ...
# 9765      0.198043 -0.498560 -0.912011  0.298990  0.738549     0.454651
# 9782      0.446665 -1.141538 -0.912011 -0.542165  0.738549    -0.163688
# 9786      0.177325 -0.107800  0.497593  0.109913  0.738549    -0.475005
# 9792      0.291276 -1.475815 -0.066248 -0.939985  0.738549     1.066549
# 9800      0.798880 -1.312051 -0.348169 -0.304546  0.738549     0.411711
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 154       0.680762         -0.576233 -0.663207  0.121464  1.856609
# 171       1.064588          1.427568 -0.047464  0.810913  1.793224
# 177       0.887647          0.158740 -0.544132  1.591078  1.948063
# 190       0.174439          0.125276 -0.826935  0.912515  1.819777
# 193       0.748816          1.148705 -0.859054  1.420530  1.877628
# ...            ...               ...       ...       ...       ...
# 9765      0.933924         -0.594192  1.417473  0.618593  2.079510
# 9782      1.192530         -0.594192 -0.703943  1.496732  1.442730
# 9786     -0.108667         -0.594192  0.743759  1.224582  2.264756
# 9792      0.923035         -0.594192 -0.526114  1.696309  1.947865
# 9800      1.415748         -0.592401 -0.399989  1.064920  1.893375
#
#       cluster_id                     tid                            artist  \
# 154           31  7L5FEYVfpIEGHJOv6gZ6EW                   ali farka touré
# 171           31  0nF3QZLQ8O1vQ4SjD3IdRS  ali farka touré, toumani diabaté
# 177           31  2fqcpLdEA1wVrL3mGNQ32v                   ali farka touré
# 190           31  3r8tadrcfrmhmzZBrn78iz                   ali farka touré
# 193           31  3Ddx0d6CGil3D7AfvrwTV4                   ali farka touré
# ...          ...                     ...                               ...
# 9765          31  07oxahRLcoeCHuXgJD8mgB                             raffi
# 9782          31  63n8zk4mEqyrTywaYVAkgz                             raffi
# 9786          31  28smxYbciKWO6pXc1DSnzp                             raffi
# 9792          31  6TRdg2K2wsSaywx1f5FZA3                             raffi
# 9800          31  0yXDWzeK9TEU6Zz53PACex                             raffi
#
#                           title
# 154      bonde (with ry cooder)
# 171                      doudou
# 177                 goydiotodam
# 190                  penda yoro
# 193                     kenouna
# ...                         ...
# 9765                 market day
# 9782         who built the ark?
# 9786  this little light of mine
# 9792           the sharing song
# 9800         the dog on the bus
#
# [125 rows x 15 columns]

# %%
# we need to reset indexes of that temporary dataframe
temp = temp.reset_index()
temp
# Out:
#      index  danceability    energy       key  loudness      mode  speechiness  \
# 0      154     -0.713571  0.112447 -0.912011 -0.833827  0.738549     0.192716
# 1      171     -0.817163 -0.388437 -0.348169 -0.021961  0.738549    -0.446020
# 2      177     -1.200456 -0.132666  1.343356 -0.881681  0.738549    -0.402006
# 3      190     -0.273303  0.485445 -0.066248  0.211121  0.738549    -0.279627
# 4      193     -1.573389 -0.050962  1.625277 -0.814713  0.738549    -0.452461
# ..     ...           ...       ...       ...       ...       ...          ...
# 120   9765      0.198043 -0.498560 -0.912011  0.298990  0.738549     0.454651
# 121   9782      0.446665 -1.141538 -0.912011 -0.542165  0.738549    -0.163688
# 122   9786      0.177325 -0.107800  0.497593  0.109913  0.738549    -0.475005
# 123   9792      0.291276 -1.475815 -0.066248 -0.939985  0.738549     1.066549
# 124   9800      0.798880 -1.312051 -0.348169 -0.304546  0.738549     0.411711
#
#      acousticness  instrumentalness  liveness   valence     tempo  cluster_id  \
# 0        0.680762         -0.576233 -0.663207  0.121464  1.856609          31
# 1        1.064588          1.427568 -0.047464  0.810913  1.793224          31
# 2        0.887647          0.158740 -0.544132  1.591078  1.948063          31
# 3        0.174439          0.125276 -0.826935  0.912515  1.819777          31
# 4        0.748816          1.148705 -0.859054  1.420530  1.877628          31
# ..            ...               ...       ...       ...       ...         ...
# 120      0.933924         -0.594192  1.417473  0.618593  2.079510          31
# 121      1.192530         -0.594192 -0.703943  1.496732  1.442730          31
# 122     -0.108667         -0.594192  0.743759  1.224582  2.264756          31
# 123      0.923035         -0.594192 -0.526114  1.696309  1.947865          31
# 124      1.415748         -0.592401 -0.399989  1.064920  1.893375          31
#
#                         tid                            artist  \
# 0    7L5FEYVfpIEGHJOv6gZ6EW                   ali farka touré
# 1    0nF3QZLQ8O1vQ4SjD3IdRS  ali farka touré, toumani diabaté
# 2    2fqcpLdEA1wVrL3mGNQ32v                   ali farka touré
# 3    3r8tadrcfrmhmzZBrn78iz                   ali farka touré
# 4    3Ddx0d6CGil3D7AfvrwTV4                   ali farka touré
# ..                      ...                               ...
# 120  07oxahRLcoeCHuXgJD8mgB                             raffi
# 121  63n8zk4mEqyrTywaYVAkgz                             raffi
# 122  28smxYbciKWO6pXc1DSnzp                             raffi
# 123  6TRdg2K2wsSaywx1f5FZA3                             raffi
# 124  0yXDWzeK9TEU6Zz53PACex                             raffi
#
#                          title
# 0       bonde (with ry cooder)
# 1                       doudou
# 2                  goydiotodam
# 3                   penda yoro
# 4                      kenouna
# ..                         ...
# 120                 market day
# 121         who built the ark?
# 122  this little light of mine
# 123           the sharing song
# 124         the dog on the bus
#
# [125 rows x 16 columns]

# %%
# generate random integer
random = randint(0, len(temp))

# %%
# what is the integer
random
# Out:
# 74

# %%
# now extract a recommendation from the temp dataframe with the random integer
title = temp.iloc[random].values[14]
artist = temp.iloc[random].values[15];
print(title)
print(artist)
# Out:
# bing crosby
# pistol packin' mama - single version

# %%
# lets put the work above in a function:

def spotify_recomendation():
    user = input("Please enter a song title: ") # get song
    a = sp.search(q=user) # search song
    track_id = (a['tracks']['items'][0]['id']) # get id
    features = sp.audio_features(tracks=track_id) # get features from id
    df_for_features = pd.DataFrame([features[0]]) # create dataframe of the features
    df_for_features = df_for_features.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis = 1) # drop unnecessary columns
    final = scaler.transform(df_for_features) # scale the features
    cluster_array=kmeans.predict(final) # predict the cluster from the scaled features
    cluster = cluster_array[0] # store in variable
    temp = musicclustered[musicclustered["cluster_id"]==cluster] # create temp dataframe
    temp = temp.reset_index() # reset index
    random = randint(0, len(temp)) # generate random variable
    
    title = temp.iloc[random].values[14] # locate variable in temp dataframe and extraxt title
    artist = temp.iloc[random].values[15] # extract artist
    return title, artist # print results

# %%
# try if it works
spotify_recomendation()
# Out:
# Please enter a song title: save your tears
# ('various artists', 'bachke rehna re baba - pukar / soundtrack version')

# %% [markdown]
# # It's working, amazing!
# lets import the MVP and see if we can put it all together

# %%
# import songs as dataframes
greatest = pd.read_csv("greatest.csv")
alltime = pd.read_csv("alltime.csv")
hot100 = pd.read_csv("hot100.csv")

# %%
# function to recommend songs
def recommend_song():
    
    user = input('Enter a song title: ')
    song_in_hot100 = False
    song_in_greatest = False
    song_in_alltime = False
    isartist = False
    
    
    if user.lower() in hot100['title'].values: # check if in hot100
        song_in_hot100 = True
    elif user.lower() in greatest['title'].values: # check if in rolling stones best hits of all time
        song_in_greatest = True
    elif user.lower() in alltime['title'].values: # check if in 100 top tits allimte
        song_in_alltime = True
    elif user.lower() in hot100['artist'].values or user.lower()in greatest['artist'].values or user.lower()in alltime['artist'].values:
        isartist = True # check if in artist column of any of these lists
        
        
    else: # this part of the function calls the spotify api and 
        a = sp.search(q=user) # search user input
        
        track_id = (a['tracks']['items'][0]['id']) # get track ID of that input
        features = sp.audio_features(tracks=track_id) # get features from track id
        df_for_features = pd.DataFrame([features[0]]) #build dataframe from the features dictionary
        df_for_features = df_for_features.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'], axis = 1) # drop columns that are unnecessary for the model
        final = scaler.transform(df_for_features) # scale features
        cluster_array=kmeans.predict(final) # get predicted cluster
        cluster = cluster_array[0] # turn cluster array into a integer number
        temp = musicclustered[musicclustered["cluster_id"]==cluster] # create new temporary dataframe that only has the cluster_id that the prediction has
        temp = temp.reset_index() # reset index of the dataframe
        random = randint(0, len(temp)) # create random integer between 0 and the number of songs on the temp dataframe
    
        
        title = temp.iloc[random].values[14] # select the column that contains the integer, extract content from title colum
        artist = temp.iloc[random].values[15] # select the column that contains the integer, extract content from songname colum
        print('Based on your awesome taste in music we recommend: ') # print recommendation
        print('---------------------------')
        print("Title: " + str(title))
        print("Artist: " + str(artist))
        again = input("Do you want to try it again? ")
        if again.lower() == 'yes':
            print("Here we go")
            recommend_song()
        else:
            print("Thanks for using our service")
        

       
    if song_in_hot100 == True: # if song is on hot 100 list, recommend one from the list
        r = randint(0, 99)
        print()
        print('That song is currently in the hot100!\nCheck this tune out:\n')
        print('---------------------------')
        title = hot100.iloc[r].values[0]
        artist = hot100.iloc[r].values[1];
        print("Title: " + str(title))
        print("Artist: " + str(artist))
        
        
    if song_in_greatest == True: # if song is in rolling stones top 500 recommend one from there
        r = randint(0, 499)
        print()
        print('That song is one of the rolling stones top 500 songs of all time!\nYou might also like this one:\n')
        print('---------------------------')
        title = greatest.iloc[r].values[0]
        artist = greatest.iloc[r].values[1];
        print("Title: " + str(title))
        print("Artist: " + str(artist))
        
        
    if song_in_alltime == True: # if song is in the third list recommend one from there
        r = randint(0, 99)
        print()
        print('That song is one of the greatest of all time!\nI can recommend this one as well:\n')
        print('---------------------------')
        title = alltime.iloc[r].values[0]
        artist = alltime.iloc[r].values[1];
        print("Title: " + str(title))
        print("Artist: " + str(artist))   
        
        
    if isartist == True: # if input is an artist, try again
        print("Hm, looks like you entered an artist. Please enter a song")
        recommend_song

# %%
recommend_song()
# Out:
# Enter a song title: highway to hell
#
# That song is one of the rolling stones top 500 songs of all time!
# You might also like this one:
#
# ---------------------------
# Title: elvis presley
# Artist: all shook up
